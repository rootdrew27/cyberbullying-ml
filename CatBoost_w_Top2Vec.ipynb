# %% [markdown]
# <a href="https://colab.research.google.com/github/rootdrew27/cyberbullying-ml/blob/main/CatBoost_w_Top2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CatBoost ImplementationC

# %%
# !pip install catboost
# !pip install tensorflow
# !pip install top2vec

# %%
# data management
import pandas as pd
import numpy as np

# preprocessing
import re

import sklearn
import tensorflow as tf

from top2vec import Top2Vec

from catboost import CatBoostClassifier, Pool, metrics, cv

# %%
df = pd.read_csv("./clean_data_2.csv", usecols=[1,2])

# %%
df.dropna(axis=0, inplace=True) #drop rows that contain any null values
df.reset_index(drop=True)
# Out:
#                                               tweet_text  cyberbullying_type
# 0             in other words your food was crapilicious                    0
# 1                                       why is so white                    0
# 2        <@> a classy whore or more red velvet cupcakes                    0
# 3      <@> gio meh p thanks for the heads up but not ...                   0
# 4      <@> this is an isis account pretending to be a...                   0
# ...                                                  ...                 ...
# 43843  black people are not expected to do anything d...                   4
# 43844  turner did not withhold his disappointment tur...                   4
# 43845  i swear to god this dumb nigger bitch i have g...                   4
# 43846  yea fuck you rt <@> if you are a nigger fuckin...                   4
# 43847  bro you got to chill rt <@> dog fuck kp that d...                   4
#
# [43848 rows x 2 columns]

# %%
def remove_mentions(text):
  return re.sub(r'<@>', r'', text)

# add a mentions count column, and a tweet length column
df['mentions_count'] = [tweet.split().count('<@>') for tweet in df.tweet_text] #number of mentions in tweet
df['tweet_text'] = df['tweet_text'].apply(remove_mentions)
df['tweet_len'] = [len(tweet.split()) for tweet in df.tweet_text] #count words in tweet
df = df[df['tweet_len'] >= 2]
df.head()
# Out:
#                                           tweet_text  cyberbullying_type  \
# 0         in other words your food was crapilicious                    0
# 1                                   why is so white                    0
# 2        a classy whore or more red velvet cupcakes                    0
# 3   gio meh p thanks for the heads up but not too...                   0
# 4   this is an isis account pretending to be a ku...                   0
#
#    mentions_count  tweet_len
# 0               0          7
# 1               0          4
# 2               1          8
# 3               1         18
# 4               1         17

# %% [markdown]
# # Generate topics using Top2Vec

# %%
t2v = Top2Vec(documents=df['tweet_text'].to_list(), embedding_model='doc2vec', speed='deep-learn')
# Out:
# 2024-04-01 00:28:20,278 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# 2024-04-01 00:28:23,484 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2024-04-01 00:56:49,761 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2024-04-01 00:58:04,378 - top2vec - INFO - Finding dense areas of documents
# INFO:top2vec:Finding dense areas of documents
# 2024-04-01 00:58:12,252 - top2vec - INFO - Finding topics
# INFO:top2vec:Finding topics

# %%
t2v.save("Top2Vec") # save the model
# t2v = Top2Vec.load("Top2Vec") # load the model

# %%
# Add the topic index to the dataframe
doc_ids = np.arange(0, df['tweet_text'].count(), 1).tolist()

topic_nums, topic_score, topic_words, word_scores = t2v.get_documents_topics(doc_ids, num_topics=1)

df['topic'] = topic_nums

# %%
df.head()
# Out:
#                                           tweet_text  cyberbullying_type  \
# 0         in other words your food was crapilicious                    0
# 1                                   why is so white                    0
# 2        a classy whore or more red velvet cupcakes                    0
# 3   gio meh p thanks for the heads up but not too...                   0
# 4   this is an isis account pretending to be a ku...                   0
#
#    mentions_count  tweet_len  topic
# 0               0          7     59
# 1               0          4     21
# 2               1          8     35
# 3               1         18     25
# 4               1         17      9

# %%
print(t2v.get_topics(10)) # NOTE: the cosine similarity score of words for each topic is fairly low (below 30%)

# %% [markdown]
# # Split the Data

# %%
X = df.drop('cyberbullying_type', axis=1)
Y = df['cyberbullying_type']

# %%
from sklearn.model_selection import train_test_split

#Split 1 - 80/20
x_Train_1, x_Test_1, y_Train_1, y_Test_1 = train_test_split(
    X,
    Y,
    test_size=.2,
    random_state=100,
    shuffle=True
)

#Split 2 - 70/30
x_Train_2, x_Test_2, y_Train_2, y_Test_2 = train_test_split(
    X,
    Y,
    test_size=.3,
    random_state=100,
    shuffle=True
)

#Split 3 - 60/40
x_Train_3, x_Test_3, y_Train_3, y_Test_3 = train_test_split(
    X,
    Y,
    test_size=.4,
    random_state=100,
    shuffle=True
)

# %% [markdown]
# # Training and Testing
#
# ---

# %%
#Try pooling

train_pool_1 = Pool(data=x_Train_1,
                  label=y_Train_1,
                  text_features=['tweet_text']
                  )
test_pool_1 = Pool(data=x_Test_1,
                 label=y_Test_1,
                 text_features=['tweet_text'])

train_pool_2 = Pool(data=x_Train_2,
                  label=y_Train_2,
                  text_features=['tweet_text']
                  )
test_pool_2 = Pool(data=x_Test_2,
                 label=y_Test_2,
                 text_features=['tweet_text'])

train_pool_3 = Pool(data=x_Train_3,
                  label=y_Train_3,
                  text_features=['tweet_text']
                  )
test_pool_3 = Pool(data=x_Test_3,
                 label=y_Test_3,
                 text_features=['tweet_text'])

# %%
def fit_model(train_pool, **kwargs):
    model = CatBoostClassifier(
        iterations=100,
        learning_rate=0.1,
        eval_metric='MultiClass',
        **kwargs
    )

    return model.fit(train_pool)

model1 = fit_model(train_pool_1)
model2 = fit_model(train_pool_2)
model3 = fit_model(train_pool_3)
# Out:
# 0:	learn: 1.5000945	total: 2.47s	remaining: 4m 4s
# 1:	learn: 1.3286903	total: 4.24s	remaining: 3m 27s
# 2:	learn: 1.2035688	total: 6.14s	remaining: 3m 18s
# 3:	learn: 1.1018824	total: 8.48s	remaining: 3m 23s
# 4:	learn: 1.0210627	total: 11.1s	remaining: 3m 30s
# 5:	learn: 0.9593787	total: 12.9s	remaining: 3m 21s
# 6:	learn: 0.9022285	total: 14.7s	remaining: 3m 15s
# 7:	learn: 0.8566447	total: 16.6s	remaining: 3m 10s
# 8:	learn: 0.8170475	total: 18.4s	remaining: 3m 6s
# 9:	learn: 0.7844974	total: 20.4s	remaining: 3m 3s
# 10:	learn: 0.7521221	total: 23.4s	remaining: 3m 9s
# 11:	learn: 0.7256577	total: 25.3s	remaining: 3m 5s
# 12:	learn: 0.7006520	total: 27.2s	remaining: 3m 1s
# 13:	learn: 0.6790634	total: 29.1s	remaining: 2m 58s
# 14:	learn: 0.6576060	total: 31.1s	remaining: 2m 56s
# 15:	learn: 0.6393843	total: 33s	remaining: 2m 53s
# 16:	learn: 0.6252342	total: 35.8s	remaining: 2m 54s
# 17:	learn: 0.6106070	total: 38s	remaining: 2m 52s
# 18:	learn: 0.5975538	total: 39.9s	remaining: 2m 50s
# 95:	learn: 0.4297680	total: 3m 12s	remaining: 8.04s
# 96:	learn: 0.4290377	total: 3m 14s	remaining: 6.02s
# 97:	learn: 0.4286399	total: 3m 16s	remaining: 4.01s
# 98:	learn: 0.4283577	total: 3m 18s	remaining: 2.01s
# 99:	learn: 0.4279003	total: 3m 20s	remaining: 0us
# 0:	learn: 1.4994992	total: 1.72s	remaining: 2m 50s
# 1:	learn: 1.3299827	total: 3.44s	remaining: 2m 48s
# 2:	learn: 1.2025349	total: 5.23s	remaining: 2m 49s
# 3:	learn: 1.1042475	total: 7.06s	remaining: 2m 49s
# 4:	learn: 1.0234404	total: 9.56s	remaining: 3m 1s
# 5:	learn: 0.9615881	total: 11.7s	remaining: 3m 2s
# 6:	learn: 0.9083404	total: 13.4s	remaining: 2m 58s
# 7:	learn: 0.8613322	total: 15.3s	remaining: 2m 55s
# 8:	learn: 0.8220508	total: 17.1s	remaining: 2m 52s
# 9:	learn: 0.7912448	total: 18.8s	remaining: 2m 49s
# 10:	learn: 0.7597040	total: 20.7s	remaining: 2m 47s
# 11:	learn: 0.7317655	total: 23.4s	remaining: 2m 51s
# 12:	learn: 0.7064665	total: 26.3s	remaining: 2m 56s
# 13:	learn: 0.6851277	total: 28.1s	remaining: 2m 52s
# 14:	learn: 0.6654400	total: 29.9s	remaining: 2m 49s
# 15:	learn: 0.6474817	total: 31.8s	remaining: 2m 46s
# 16:	learn: 0.6315797	total: 33.6s	remaining: 2m 44s
# 17:	learn: 0.6174028	total: 36.5s	remaining: 2m 46s
# 18:	learn: 0.6043424	total: 38.3s	remaining: 2m 43s
# 19:	learn: 0.5921347	total: 40.2s	remaining: 2m 40s
# 20:	learn: 0.5813552	total: 42s	remaining: 2m 37s
# 21:	learn: 0.5730863	total: 43.7s	remaining: 2m 35s
# 22:	learn: 0.5654701	total: 45.5s	remaining: 2m 32s
# 23:	learn: 0.5564537	total: 47.8s	remaining: 2m 31s
# 24:	learn: 0.5489362	total: 50.2s	remaining: 2m 30s
# 25:	learn: 0.5411001	total: 51.9s	remaining: 2m 27s
# 26:	learn: 0.5350728	total: 53.6s	remaining: 2m 24s
# 27:	learn: 0.5285942	total: 55.4s	remaining: 2m 22s
# 28:	learn: 0.5232009	total: 57.2s	remaining: 2m 19s
# 29:	learn: 0.5194129	total: 58.9s	remaining: 2m 17s
# 30:	learn: 0.5159587	total: 1m 1s	remaining: 2m 16s
# 31:	learn: 0.5130600	total: 1m 3s	remaining: 2m 14s
# 32:	learn: 0.5095043	total: 1m 5s	remaining: 2m 12s
# 33:	learn: 0.5073073	total: 1m 6s	remaining: 2m 9s
# 34:	learn: 0.5032237	total: 1m 8s	remaining: 2m 7s
# 35:	learn: 0.4998322	total: 1m 10s	remaining: 2m 4s
# 36:	learn: 0.4963628	total: 1m 12s	remaining: 2m 2s
# 37:	learn: 0.4937094	total: 1m 14s	remaining: 2m 1s
# 38:	learn: 0.4902736	total: 1m 16s	remaining: 1m 59s
# 39:	learn: 0.4874333	total: 1m 18s	remaining: 1m 57s
# 40:	learn: 0.4853499	total: 1m 20s	remaining: 1m 55s
# 41:	learn: 0.4835429	total: 1m 21s	remaining: 1m 52s
# 42:	learn: 0.4817491	total: 1m 23s	remaining: 1m 50s
# 43:	learn: 0.4804365	total: 1m 25s	remaining: 1m 48s
# 44:	learn: 0.4788606	total: 1m 27s	remaining: 1m 47s
# 45:	learn: 0.4762563	total: 1m 29s	remaining: 1m 45s
# 46:	learn: 0.4749376	total: 1m 31s	remaining: 1m 42s
# 47:	learn: 0.4738161	total: 1m 33s	remaining: 1m 40s
# 48:	learn: 0.4720658	total: 1m 34s	remaining: 1m 38s
# 49:	learn: 0.4708849	total: 1m 36s	remaining: 1m 36s
# 50:	learn: 0.4689648	total: 1m 38s	remaining: 1m 34s
# 51:	learn: 0.4673212	total: 1m 40s	remaining: 1m 32s
# 52:	learn: 0.4661611	total: 1m 42s	remaining: 1m 30s
# 53:	learn: 0.4651770	total: 1m 44s	remaining: 1m 28s
# 54:	learn: 0.4647433	total: 1m 45s	remaining: 1m 26s
# 55:	learn: 0.4633292	total: 1m 47s	remaining: 1m 24s
# 56:	learn: 0.4613054	total: 1m 49s	remaining: 1m 22s
# 57:	learn: 0.4600238	total: 1m 51s	remaining: 1m 20s
# 58:	learn: 0.4587329	total: 1m 53s	remaining: 1m 18s
# 59:	learn: 0.4581357	total: 1m 55s	remaining: 1m 17s
# 60:	learn: 0.4577447	total: 1m 57s	remaining: 1m 14s
# 61:	learn: 0.4571940	total: 1m 58s	remaining: 1m 12s
# 62:	learn: 0.4556443	total: 2m	remaining: 1m 10s
# 63:	learn: 0.4549208	total: 2m 2s	remaining: 1m 8s
# 64:	learn: 0.4545345	total: 2m 3s	remaining: 1m 6s
# 65:	learn: 0.4539249	total: 2m 6s	remaining: 1m 4s
# 66:	learn: 0.4524705	total: 2m 8s	remaining: 1m 3s
# 67:	learn: 0.4519311	total: 2m 9s	remaining: 1m 1s
# 68:	learn: 0.4518015	total: 2m 11s	remaining: 59.1s
# 69:	learn: 0.4516483	total: 2m 13s	remaining: 57.1s
# 70:	learn: 0.4509879	total: 2m 14s	remaining: 55.1s
# 71:	learn: 0.4508040	total: 2m 16s	remaining: 53.1s
# 72:	learn: 0.4502658	total: 2m 18s	remaining: 51.3s
# 73:	learn: 0.4490548	total: 2m 20s	remaining: 49.5s
# 74:	learn: 0.4478942	total: 2m 22s	remaining: 47.5s
# 75:	learn: 0.4472513	total: 2m 24s	remaining: 45.5s
# 76:	learn: 0.4458911	total: 2m 25s	remaining: 43.6s
# 77:	learn: 0.4456280	total: 2m 27s	remaining: 41.6s
# 78:	learn: 0.4446154	total: 2m 29s	remaining: 39.7s
# 79:	learn: 0.4441647	total: 2m 31s	remaining: 37.9s
# 80:	learn: 0.4439561	total: 2m 33s	remaining: 36.1s
# 81:	learn: 0.4432597	total: 2m 35s	remaining: 34.1s
# 82:	learn: 0.4422230	total: 2m 37s	remaining: 32.2s
# 83:	learn: 0.4415836	total: 2m 38s	remaining: 30.3s
# 84:	learn: 0.4408905	total: 2m 40s	remaining: 28.4s
# 85:	learn: 0.4403159	total: 2m 42s	remaining: 26.4s
# 86:	learn: 0.4398687	total: 2m 44s	remaining: 24.6s
# 87:	learn: 0.4396114	total: 2m 46s	remaining: 22.7s
# 88:	learn: 0.4389431	total: 2m 48s	remaining: 20.8s
# 89:	learn: 0.4381742	total: 2m 50s	remaining: 18.9s
# 90:	learn: 0.4377776	total: 2m 51s	remaining: 17s
# 91:	learn: 0.4376659	total: 2m 53s	remaining: 15.1s
# 92:	learn: 0.4373705	total: 2m 55s	remaining: 13.2s
# 93:	learn: 0.4368169	total: 2m 57s	remaining: 11.3s
# 94:	learn: 0.4362399	total: 2m 59s	remaining: 9.45s
# 95:	learn: 0.4356073	total: 3m 1s	remaining: 7.55s
# 96:	learn: 0.4349486	total: 3m 2s	remaining: 5.66s
# 97:	learn: 0.4344223	total: 3m 4s	remaining: 3.77s
# 98:	learn: 0.4337932	total: 3m 6s	remaining: 1.88s
# 99:	learn: 0.4328561	total: 3m 7s	remaining: 0us

# %%
y_pred_1 = [pred[0] for pred in model1.predict(test_pool_1)]
y_pred_2 = [pred[0] for pred in model2.predict(test_pool_2)]
y_pred_3 = [pred[0] for pred in model3.predict(test_pool_3)]

# %%
from catboost.utils import eval_metric


y_Test_1 = np.array(y_Test_1)
y_Test_2 = np.array(y_Test_2)
y_Test_3 = np.array(y_Test_3)

y_pred_1 = np.array(y_pred_1)
y_pred_2 = np.array(y_pred_2)
y_pred_3 = np.array(y_pred_3)

acc1 = eval_metric(y_Test_1, y_pred_1, 'Accuracy')
acc2 = eval_metric(y_Test_2, y_pred_2, 'Accuracy')
acc3 = eval_metric(y_Test_3, y_pred_3, 'Accuracy')

prec1 = eval_metric(y_Test_1, y_pred_1, 'Precision')
prec2 = eval_metric(y_Test_2, y_pred_2, 'Precision')
prec3 = eval_metric(y_Test_3, y_pred_3, 'Precision')


F1_1 = eval_metric(y_Test_1, y_pred_1, 'F1')
F1_2 = eval_metric(y_Test_2, y_pred_2, 'F1')
F1_3 = eval_metric(y_Test_3, y_pred_3, 'F1')


recall_1 = eval_metric(y_Test_1, y_pred_1, 'Recall')
recall_2 = eval_metric(y_Test_2, y_pred_2, 'Recall')
recall_3 = eval_metric(y_Test_3, y_pred_3, 'Recall')

# %%
print(acc1)
print(acc2)
print(acc3)
# Out:
# [0.8673761299919899]
# [0.8673329264571255]
# [0.8692567374263318]

# %%
print(prec1)
print(prec2)
print(prec3)
# Out:
# [0.91208360548661]
# [0.9123724823437092]
# [0.9126823206226699]

# %%
print(F1_1)
print(F1_2)
print(F1_3)
# Out:
# [0.9233617668452027]
# [0.9232805399920591]
# [0.9243202066704204]

# %%
print(recall_1)
print(recall_2)
print(recall_3)
# Out:
# [0.9349223352972683]
# [0.9344525808180032]
# [0.9362587224906066]
