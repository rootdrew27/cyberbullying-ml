# %%
# !pip install catboost
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# Requirement already satisfied: catboost in /data/users/roota5351/.local/lib/python3.9/site-packages (1.2.3)
# Requirement already satisfied: six in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: numpy>=1.16.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from catboost) (1.24.2)
# Requirement already satisfied: pandas>=0.24 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from catboost) (2.0.0)
# Requirement already satisfied: matplotlib in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from catboost) (3.7.1)
# Requirement already satisfied: scipy in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /data/users/roota5351/.local/lib/python3.9/site-packages (from catboost) (5.20.0)
# Requirement already satisfied: graphviz in /data/users/roota5351/.local/lib/python3.9/site-packages (from catboost) (0.20.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: pillow>=6.2.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from matplotlib->catboost) (9.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /data/users/roota5351/.local/lib/python3.9/site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: zipp>=3.1.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# Requirement already satisfied: tensorflow in /data/users/roota5351/.local/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: six>=1.12.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (1.24.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorflow) (24.3.7)
# Requirement already satisfied: astunparse>=1.6.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: packaging in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (23.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: libclang>=13.0.0 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /data/users/roota5351/.local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.17.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (6.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /data/software/python-libs/3.0.0/envs/tensorflow-2.11-gpu/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/data/users/roota5351/.local/lib/python3.9/site-packages)

# %%
# data management
import pandas as pd
import numpy as np

# preprocessing
import re

import sklearn
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

import tensorflow as tf

from catboost import CatBoostClassifier, Pool, metrics, cv
# Out:
# 2024-04-13 18:51:31.781881: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-13 18:51:32.640118: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /data/software/default/openblas/0.3.15/lib:/data/software/default/cuda/11.4/lib64
# 2024-04-13 18:51:32.640196: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /data/software/default/openblas/0.3.15/lib:/data/software/default/cuda/11.4/lib64
# 2024-04-13 18:51:32.640201: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
df = pd.read_csv("./clean_data_2.csv", usecols=[1,2])

# %%
df.dropna(axis=0, inplace=True) #drop rows that contain any null values
df.reset_index(drop=True)

def remove_mentions(text):
  return re.sub(r'<@>', r'', text)

# add a mentions count column, and a tweet length column
df['mentions_count'] = [tweet.split().count('<@>') for tweet in df.tweet_text] #number of mentions in tweet
df['tweet_text'] = df['tweet_text'].apply(remove_mentions)
df['tweet_len'] = [len(tweet.split()) for tweet in df.tweet_text] #count words in tweet
df = df[df['tweet_len'] >= 2]
df.head()
# Out:
#                                           tweet_text  cyberbullying_type
# 0         in other words your food was crapilicious                    0  \
# 1                                   why is so white                    0
# 2        a classy whore or more red velvet cupcakes                    0
# 3   gio meh p thanks for the heads up but not too...                   0
# 4   this is an isis account pretending to be a ku...                   0
#
#    mentions_count  tweet_len
# 0               0          7
# 1               0          4
# 2               1          8
# 3               1         18
# 4               1         17

# %%
df[df.cyberbullying_type == 5]
# Out:
#                                               tweet_text  cyberbullying_type
# 23882   fyi it looks like i was caught by it i am not...                   5  \
# 23883  i need to just switch to an organization based...                   5
# 23884  rmaed my monoprice shoddy power bricks on thos...                   5
# 23886   life continues i have got the code to interpr...                   5
# 23887   did not mention your name i call out behavior...                   5
# ...                                                  ...                 ...
# 31700                                        no that is                    5
# 31701           why are you giving these idiots airtime                    5
# 31702  i am right now watching enforcers defend chums...                   5
# 31703       misandry is not a word ios can autocomplete                    5
# 31704    mom i think poor  is being harassed and bull...                   5
#
#        mentions_count  tweet_len
# 23882               1         15
# 23883               0         22
# 23884               0         22
# 23886               0         22
# 23887               1         11
# ...               ...        ...
# 31700               3          3
# 31701               1          7
# 31702               0         10
# 31703               0          8
# 31704               3         22
#
# [6777 rows x 4 columns]

# %%
df = df.drop(df[df.cyberbullying_type == 5].index)

# %%
df.cyberbullying_type.value_counts()
# Out:
# cyberbullying_type
# 2    7768
# 1    7660
# 3    7511
# 4    7429
# 0    6546
# Name: count, dtype: int64

# %%
X = df.drop('cyberbullying_type', axis=1)
Y = df['cyberbullying_type']

# %%
from sklearn.model_selection import train_test_split

#Split 1 - 80/20
x_Train_1, x_Test_1, y_Train_1, y_Test_1 = train_test_split(
    X,
    Y,
    test_size=.2,
    random_state=100,
    shuffle=True
)

#Split 2 - 70/30
x_Train_2, x_Test_2, y_Train_2, y_Test_2 = train_test_split(
    X,
    Y,
    test_size=.3,
    random_state=100,
    shuffle=True
)

#Split 3 - 60/40
x_Train_3, x_Test_3, y_Train_3, y_Test_3 = train_test_split(
    X,
    Y,
    test_size=.4,
    random_state=100,
    shuffle=True
)

# %%
#Try pooling

train_pool_1 = Pool(data=x_Train_1,
                  label=y_Train_1,
                  text_features=['tweet_text']
                  )
test_pool_1 = Pool(data=x_Test_1,
                 label=y_Test_1,
                 text_features=['tweet_text'])

train_pool_2 = Pool(data=x_Train_2,
                  label=y_Train_2,
                  text_features=['tweet_text']
                  )

test_pool_2 = Pool(data=x_Test_2,
                 label=y_Test_2,
                 text_features=['tweet_text'])

train_pool_3 = Pool(data=x_Train_3,
                  label=y_Train_3,
                  text_features=['tweet_text']
                  )
test_pool_3 = Pool(data=x_Test_3,
                 label=y_Test_3,
                 text_features=['tweet_text'])
# Out:
# TBB Warning: The number of workers is currently limited to 4. The request for 63 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.

# %%
# params = {
#     'iterations': 100,
#     'learning_rate': 0.1,
#     'eval_metric': 'MultiClass'
# }

# %%
def fit_model(train_pool):
    model = CatBoostClassifier(
        iterations=100,
        learning_rate=0.1,
        eval_metric='MultiClass',
    )

    return model.fit(train_pool)

model1 = fit_model(train_pool_1)
model2 = fit_model(train_pool_2)
model3 = fit_model(train_pool_3)
# Out:
# 0:	learn: 1.3256290	total: 336ms	remaining: 33.3s
# 1:	learn: 1.1506684	total: 678ms	remaining: 33.2s
# 2:	learn: 1.0201835	total: 1.03s	remaining: 33.2s
# 3:	learn: 0.9157042	total: 1.34s	remaining: 32.2s
# 4:	learn: 0.8308699	total: 1.67s	remaining: 31.7s
# 5:	learn: 0.7608031	total: 2.09s	remaining: 32.8s
# 6:	learn: 0.7045363	total: 2.5s	remaining: 33.2s
# 7:	learn: 0.6543088	total: 2.9s	remaining: 33.4s
# 8:	learn: 0.6151904	total: 3.29s	remaining: 33.3s
# 9:	learn: 0.5778157	total: 3.69s	remaining: 33.2s
# 10:	learn: 0.5463491	total: 4.1s	remaining: 33.2s
# 11:	learn: 0.5177749	total: 4.5s	remaining: 33s
# 12:	learn: 0.4917117	total: 4.92s	remaining: 32.9s
# 13:	learn: 0.4695397	total: 5.32s	remaining: 32.7s
# 14:	learn: 0.4484259	total: 5.74s	remaining: 32.5s
# 15:	learn: 0.4304174	total: 6.14s	remaining: 32.2s
# 16:	learn: 0.4141956	total: 6.57s	remaining: 32.1s
# 17:	learn: 0.4006426	total: 6.96s	remaining: 31.7s
# 18:	learn: 0.3880282	total: 7.29s	remaining: 31.1s
# 19:	learn: 0.3768268	total: 7.64s	remaining: 30.6s
# 20:	learn: 0.3655910	total: 7.99s	remaining: 30.1s
# 21:	learn: 0.3560029	total: 8.33s	remaining: 29.5s
# 22:	learn: 0.3476407	total: 8.69s	remaining: 29.1s
# 23:	learn: 0.3396054	total: 9.03s	remaining: 28.6s
# 23:	learn: 0.3432366	total: 7.64s	remaining: 24.2s
# 24:	learn: 0.3356772	total: 7.96s	remaining: 23.9s
# 25:	learn: 0.3291602	total: 8.26s	remaining: 23.5s
# 26:	learn: 0.3239573	total: 8.57s	remaining: 23.2s
# 27:	learn: 0.3191439	total: 8.86s	remaining: 22.8s
# 28:	learn: 0.3142798	total: 9.17s	remaining: 22.5s
# 29:	learn: 0.3094959	total: 9.47s	remaining: 22.1s
# 30:	learn: 0.3044869	total: 9.81s	remaining: 21.8s
# 31:	learn: 0.3008983	total: 10.1s	remaining: 21.5s
# 32:	learn: 0.2965660	total: 10.4s	remaining: 21.1s
# 33:	learn: 0.2939224	total: 10.7s	remaining: 20.8s
# 34:	learn: 0.2904305	total: 11s	remaining: 20.5s
# 35:	learn: 0.2879844	total: 11.3s	remaining: 20.1s
# 36:	learn: 0.2851990	total: 11.6s	remaining: 19.8s
# 37:	learn: 0.2823953	total: 11.9s	remaining: 19.4s
# 38:	learn: 0.2794844	total: 12.2s	remaining: 19.1s
# 39:	learn: 0.2773019	total: 12.5s	remaining: 18.8s
# 40:	learn: 0.2752269	total: 12.8s	remaining: 18.5s
# 41:	learn: 0.2734289	total: 13.1s	remaining: 18.1s
# 42:	learn: 0.2711629	total: 13.4s	remaining: 17.8s
# 43:	learn: 0.2698370	total: 13.7s	remaining: 17.5s
# 44:	learn: 0.2684071	total: 14s	remaining: 17.1s
# 45:	learn: 0.2674647	total: 14.3s	remaining: 16.8s
# 46:	learn: 0.2665795	total: 14.6s	remaining: 16.5s
# 47:	learn: 0.2652581	total: 14.9s	remaining: 16.1s
# 48:	learn: 0.2641019	total: 15.2s	remaining: 15.8s
# 49:	learn: 0.2631856	total: 15.5s	remaining: 15.5s
# 50:	learn: 0.2617488	total: 15.8s	remaining: 15.2s
# 51:	learn: 0.2605154	total: 16.1s	remaining: 14.8s
# 52:	learn: 0.2594770	total: 16.4s	remaining: 14.5s
# 53:	learn: 0.2578242	total: 16.7s	remaining: 14.2s
# 54:	learn: 0.2569420	total: 17s	remaining: 13.9s
# 55:	learn: 0.2566132	total: 17.2s	remaining: 13.5s
# 56:	learn: 0.2555201	total: 17.5s	remaining: 13.2s
# 57:	learn: 0.2545153	total: 17.8s	remaining: 12.9s
# 58:	learn: 0.2532579	total: 18.2s	remaining: 12.6s
# 59:	learn: 0.2525873	total: 18.5s	remaining: 12.3s
# 60:	learn: 0.2519349	total: 18.8s	remaining: 12s
# 61:	learn: 0.2514716	total: 19.1s	remaining: 11.7s
# 62:	learn: 0.2511525	total: 19.4s	remaining: 11.4s
# 63:	learn: 0.2510635	total: 19.6s	remaining: 11s
# 64:	learn: 0.2504504	total: 19.9s	remaining: 10.7s
# 65:	learn: 0.2493680	total: 20.2s	remaining: 10.4s
# 66:	learn: 0.2481757	total: 20.5s	remaining: 10.1s
# 67:	learn: 0.2478873	total: 20.8s	remaining: 9.8s
# 68:	learn: 0.2475433	total: 21.1s	remaining: 9.48s
# 69:	learn: 0.2466741	total: 21.4s	remaining: 9.17s
# 70:	learn: 0.2464736	total: 21.7s	remaining: 8.86s
# 71:	learn: 0.2457643	total: 22s	remaining: 8.55s
# 72:	learn: 0.2453083	total: 22.3s	remaining: 8.23s
# 73:	learn: 0.2448709	total: 22.6s	remaining: 7.93s
# 74:	learn: 0.2444739	total: 22.9s	remaining: 7.62s
# 75:	learn: 0.2441040	total: 23.1s	remaining: 7.31s
# 76:	learn: 0.2433891	total: 23.4s	remaining: 7s
# 77:	learn: 0.2428154	total: 23.7s	remaining: 6.7s
# 78:	learn: 0.2422291	total: 24s	remaining: 6.39s
# 79:	learn: 0.2409724	total: 24.3s	remaining: 6.08s
# 80:	learn: 0.2401104	total: 24.6s	remaining: 5.78s
# 81:	learn: 0.2399791	total: 24.9s	remaining: 5.47s
# 82:	learn: 0.2393632	total: 25.2s	remaining: 5.16s
# 83:	learn: 0.2390174	total: 25.5s	remaining: 4.86s
# 84:	learn: 0.2383887	total: 25.8s	remaining: 4.55s
# 85:	learn: 0.2377923	total: 26.1s	remaining: 4.25s
# 86:	learn: 0.2373031	total: 26.5s	remaining: 3.96s
# 87:	learn: 0.2366779	total: 26.8s	remaining: 3.65s
# 88:	learn: 0.2363115	total: 27.1s	remaining: 3.34s
# 89:	learn: 0.2356118	total: 27.4s	remaining: 3.04s
# 90:	learn: 0.2354807	total: 27.6s	remaining: 2.73s
# 91:	learn: 0.2351698	total: 27.9s	remaining: 2.43s
# 92:	learn: 0.2349351	total: 28.2s	remaining: 2.12s
# 93:	learn: 0.2347650	total: 28.5s	remaining: 1.82s
# 94:	learn: 0.2344363	total: 28.8s	remaining: 1.51s
# 95:	learn: 0.2343858	total: 29.1s	remaining: 1.21s
# 96:	learn: 0.2340392	total: 29.4s	remaining: 910ms
# 97:	learn: 0.2331770	total: 29.7s	remaining: 606ms
# 98:	learn: 0.2326574	total: 30s	remaining: 303ms
# 99:	learn: 0.2321186	total: 30.3s	remaining: 0us

# %%
y_pred_1 = [pred[0] for pred in model1.predict(test_pool_1)]
y_pred_2 = [pred[0] for pred in model2.predict(test_pool_2)]
y_pred_3 = [pred[0] for pred in model3.predict(test_pool_3)]

# %%
test_pools = [test_pool_1, test_pool_2, test_pool_3]
models = [model1, model2, model3]

# %%
Model_1_Results = 'Model 1 Accuracy : {0:0.4f}\n'. format(accuracy_score(y_Test_1, y_pred_1)) + '\nModel 1 Classification Report:\n' + classification_report(y_Test_1, y_pred_1) + '\n\n'

Model_2_Results = 'Model 2 Accuracy : {0:0.4f}\n'. format(accuracy_score(y_Test_2, y_pred_2)) + '\nModel 2 Classification Report:\n' + classification_report(y_Test_2, y_pred_2) + '\n\n'

Model_3_Results = 'Model 3 Accuracy : {0:0.4f}\n'. format(accuracy_score(y_Test_3, y_pred_3)) + '\nModel 3 Classification Report:\n' + classification_report(y_Test_3, y_pred_3) + '\n\n'

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

conf1 = confusion_matrix(y_Test_1, y_pred_1, normalize='pred')
ConfusionMatrixDisplay(conf1).plot()

# %%
# filename = "catboost_results_2.txt"

# with open(filename, 'w') as f:
#   f.write('Model 1 Params:\n' + str(model1.get_params())+ '\n\n')
#   f.write(Model_1_Results + '\n\n')
#   f.write('Model 2 Params:\n' + str(model2.get_params())+ '\n\n')
#   f.write(Model_2_Results + '\n\n')
#   f.write('Model 3 Params:\n' + str(model3.get_params())+ '\n\n')
#   f.write(Model_3_Results + '\n\n')
#   f.close()
